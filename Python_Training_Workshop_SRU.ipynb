# %% [markdown]
# <a href="https://colab.research.google.com/github/pikupankaj/Python-Training-Workshop/blob/main/Python_Training_Workshop_SRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Day-1**
# Day-1 (21/07/2026)

# %%
import keyword
print("standrd keyword=", len(keyword.kwlist))
print("soft keyword=", keyword.softkwlist)
print("all keyword=", keyword.kwlist)
# Out:
# standrd keyword= 35
# soft keyword= ['_', 'case', 'match', 'type']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=5
y="Python"
z=3.5
print(x)
print(y)
print(z)
print(type(x))
print(type(y))
print(type(z))
# Out:
# 5
# Python
# 3.5
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
y1=2
print(y1)
print(type(y1))
y2=float(y1)
print(y2)
print(type(y2))
y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
y1=int(2)
y2=float(2)
y3=str(2)
print(y1)
print(y2)
print(y3)
print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
c=50
d=float(c)
print(d)
# Out:
# 50.0

# %%
a=2
A="Rammana"
print(a)
print(A)
# Out:
# 2
# Rammana

# %%
myname="pankaj"
my_dept="ME_Dept"
_my_university="SRU"
myLocation="Hanamakonda"
State="Telangana"
print(myname)
print(my_dept)
print(_my_university)
print(myLocation)
print(State)
# Out:
# pankaj
# ME_Dept
# SRU
# Hanamakonda
# Telangana

# %% [markdown]
# **Day-1 Assignments**

# %%
length=10
breadth=20
first="Mohandas"
middle="Karamchand"
last="Gandhi"
print(length)
print(breadth)
print(first)
print(middle)
print(last)
fullname=[first,middle,last]
fullname = first + " " + middle + " " + last
print("Full Name:", fullname)
# Out:
# 10
# 20
# Mohandas
# Karamchand
# Gandhi
# Full Name: Mohandas Karamchand Gandhi

# %% [markdown]
# **Day-2: Prompt Engineering, AI Code Generation, Operators, Conditional Statements**

# %%
import math
radious=float(input("Enter the Radious of the Circle: "))
area=math(radious**2)
print("area")
# Out:
# Enter the Radious of the Circle: 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2737/922789839.py in <cell line: 0>()
#       1 import math
#       2 radious=float(input("Enter the Radious of the Circle: "))
# ----> 3 area=math(radious**2)
#       4 print("area")
#
# TypeError: 'module' object is not callable
